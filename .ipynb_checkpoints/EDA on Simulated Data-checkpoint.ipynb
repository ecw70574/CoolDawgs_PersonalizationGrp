# %% [markdown]
# # EDA on Simulated Data

# %% [markdown]
# ## Goal
# Understand how different dog features and environmental conditions in the simulated data affect core body temperature (CBT) and heat risk to identify which factors are important for predicting CBT and detecting heat stress.

# %% [markdown]
# ## Objectives
# * Understand dataset structure
# * Summarize feature distributions
# * Identify outliers and skews
# * Visualize key models
# * Relations with CBT (risk, weight, height)
# * Univariations

# %% [markdown]
# ## Datasets
# * Main Dataset: FullSimDF.csv
# * Other Reference Datasets:
#    * breed_traits_long.csv
#    * breed_traits_long.csv
#    * breed_traits.csv
#    * trait_descriptions.csv
#    * breed_rank.csv
#    * dogs_dataset.csv
#    * dogs_dataset_EDA.csv

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Inspecting Dataset Structure
# * Check for missing values
# * Identify categorical and numerical features

# %%
# Load simulated dataset
df = pd.read_csv("FullSimDF.csv") # read dataset for simulated data
print(f"Simulated Data: \nRows: {df.shape[0]}, Columns: {df.shape[1]}\n") # display row and cols count
print("---Preview---")
display(df.head()) # preview first five rows of data set
# Out:
# Simulated Data:
# Rows: 9335, Columns: 39
#
# ---Preview---
#                 Breed   Age  Weight  Gender          Color Coat Length  \
# 0          Rottweiler   7.4    18.2  Female           Gray       Short
# 1              Poodle  11.3    61.3    Male        Brindle        Long
# 2    Airedale Terrier  10.0    37.5    Male          Merle       Short
# 3            Havanese   6.5    52.6    Male            Red        Long
# 4  Labrador Retriever   5.8    45.4  Female  Black and Tan       Short
#
#   Coat Type  Energy Level  Playfulness Level  is_brachycephalic  ... Hum_Diff  \
# 0    Smooth           3.0                4.0                0.0  ...     1.73
# 1     Curly           4.0                5.0                0.0  ...     9.73
# 2      Wiry           3.0                3.0                0.0  ...     4.71
# 3    Double           3.0                5.0                0.0  ...     8.38
# 4    Double           5.0                5.0                0.0  ...     6.47
#
#    CBT_simulated is_old is_overweight  heat_stress_risk  \
# 0      38.247775      0             0                 0
# 1      39.811340      0             0                 0
# 2      38.629803      0             0                 0
# 3      39.634108      0             0                 0
# 4      39.268502      0             0                 0
#
#    High_humidity_fordogs  prior_heat_related_injury_est  \
# 0                      0                          0.000
# 1                      1                          0.022
# 2                      1                          0.012
# 3                      0                          0.002
# 4                      0                          0.022
#
#    simulated_heat_injury_flag  target2Category  target3Category
# 0                           0                0           Normal
# 1                           0                1      Heat Stress
# 2                           0                0           Normal
# 3                           0                0           Normal
# 4                           0                0           Normal
#
# [5 rows x 39 columns]

# %%
# Check for any missing values
if df.isnull().values.any() == False:
    print("No missing values found ✅")
else:
    df.isnull().sum()
# Out:
# No missing values found ✅

# %%
# Summary table
print("---Summary Table---")
info_df = pd.DataFrame({
    "Data Type": df.dtypes,
    "Non-null Count": df.notnull().sum(),
    "Null Count": df.isnull().sum(),
    "Unique Values": df.nunique()
    
})

numeric_cols = df.select_dtypes(include=["int64","float64"])
numeric_cols = numeric_cols.loc[:, numeric_cols.nunique() > 2].columns.tolist()
categorical_cols = df.select_dtypes(include=["str"])
categorical_cols = categorical_cols.loc[:, categorical_cols.nunique() > 2].columns.tolist()
bool_cols = df.columns[df.nunique() == 2].tolist()

print(f"\nCommon Data Type: {info_df["Data Type"].mode()[0]}") # displays the common data type amongst columns
print(f"\nNumeric Attributes: {", ".join(numeric_cols)}") # lists columns that are numeric
print(f"\nNumeric Attributes Count: {len(numeric_cols)}")
print(f"\nCategorical Attributes: {", ".join(categorical_cols)}") # lists columns are that categorical
print(f"\nNumeric Attributes Count: {len(categorical_cols)}")
print(f"\nBoolean Attributes: {", ".join(bool_cols)}") # lists columns that are boolean (0/1 or true/false)
print(f"\nNumeric Attributes Count: {len(bool_cols)}")

info_df
# Out:
# ---Summary Table---
#
# Common Data Type: float64
#
# Numeric Attributes: Age, Weight, Energy Level, Playfulness Level, Sun Exposure, Wind Cooling Effect, Station_Temp, Station_Humidity, Ambient_Temp, Ambient_Humidity, T_device, H_device, breed_wt_mu, breed_wt_sd, ideal_weight, pct_of_ideal, BCS_cont, BCS, Temp_Diff, Hum_Diff, CBT_simulated, prior_heat_related_injury_est
#
# Numeric Attributes Count: 22
#
# Categorical Attributes: Breed, Color, Coat Length, Coat Type, size_category, Season, target3Category
#
# Numeric Attributes Count: 7
#
# Boolean Attributes: Gender, is_brachycephalic, Spayed/Neutered, Indoor/Outdoor, is_old, is_overweight, heat_stress_risk, High_humidity_fordogs, simulated_heat_injury_flag, target2Category
#
# Numeric Attributes Count: 10
#                               Data Type  Non-null Count  Null Count  \
# Breed                               str            9335           0
# Age                             float64            9335           0
# Weight                          float64            9335           0
# Gender                              str            9335           0
# Color                               str            9335           0
# Coat Length                         str            9335           0
# Coat Type                           str            9335           0
# Energy Level                    float64            9335           0
# Playfulness Level               float64            9335           0
# is_brachycephalic               float64            9335           0
# size_category                       str            9335           0
# Spayed/Neutered                   int64            9335           0
# Indoor/Outdoor                      str            9335           0
# Season                              str            9335           0
# Sun Exposure                    float64            9335           0
# Wind Cooling Effect             float64            9335           0
# Station_Temp                    float64            9335           0
# Station_Humidity                float64            9335           0
# Ambient_Temp                    float64            9335           0
# Ambient_Humidity                float64            9335           0
# T_device                        float64            9335           0
# H_device                        float64            9335           0
# breed_wt_mu                     float64            9335           0
# breed_wt_sd                     float64            9335           0
# ideal_weight                    float64            9335           0
# pct_of_ideal                    float64            9335           0
# BCS_cont                        float64            9335           0
# BCS                               int64            9335           0
# Temp_Diff                       float64            9335           0
# Hum_Diff                        float64            9335           0
# CBT_simulated                   float64            9335           0
# is_old                            int64            9335           0
# is_overweight                     int64            9335           0
# heat_stress_risk                  int64            9335           0
# High_humidity_fordogs             int64            9335           0
# prior_heat_related_injury_est   float64            9335           0
# simulated_heat_injury_flag        int64            9335           0
# target2Category                   int64            9335           0
# target3Category                     str            9335           0
#
#                                Unique Values
# Breed                                     46
# Age                                      256
# Weight                                   842
# Gender                                     2
# Color                                     16
# Coat Length                                3
# Coat Type                                  6
# Energy Level                               3
# Playfulness Level                          3
# is_brachycephalic                          2
# size_category                              5
# Spayed/Neutered                            2
# Indoor/Outdoor                             2
# Season                                     4
# Sun Exposure                            1837
# Wind Cooling Effect                     1837
# Station_Temp                            9335
# Station_Humidity                        9061
# Ambient_Temp                            1950
# Ambient_Humidity                        2473
# T_device                                2144
# H_device                                2807
# breed_wt_mu                               46
# breed_wt_sd                               46
# ideal_weight                            9335
# pct_of_ideal                            9335
# BCS_cont                                9335
# BCS                                        9
# Temp_Diff                                987
# Hum_Diff                                1557
# CBT_simulated                           9323
# is_old                                     2
# is_overweight                              2
# heat_stress_risk                           2
# High_humidity_fordogs                      2
# prior_heat_related_injury_est             11
# simulated_heat_injury_flag                 2
# target2Category                            2
# target3Category                            3

# %% [markdown]
# ## Summary Statistics and Feature Distributions
# * Calculate statistical summaries (categorical and numerical)
# * Visualize feature distributions
# * Identify outliers and skewed distributions
# * Identify imbalanced categories

# %%
# Summary statistics
print("---Summary Statistics---")
df.describe(include='all')
# Out:
# ---Summary Statistics---
#                     Breed          Age       Weight  Gender Color Coat Length  \
# count                9335  9335.000000  9335.000000    9335  9335        9335
# unique                 46          NaN          NaN       2    16           3
# top     Doberman Pinscher          NaN          NaN  Female   Red       Short
# freq                  470          NaN          NaN    4746   634        5087
# mean                  NaN     7.399721    32.184821     NaN   NaN         NaN
# std                   NaN     4.045858    15.839744     NaN   NaN         NaN
# min                   NaN    -8.600000   -32.000000     NaN   NaN         NaN
# 25%                   NaN     4.700000    21.300000     NaN   NaN         NaN
# 50%                   NaN     7.400000    32.200000     NaN   NaN         NaN
# 75%                   NaN    10.200000    42.800000     NaN   NaN         NaN
# max                   NaN    22.300000    98.200000     NaN   NaN         NaN
#
#        Coat Type  Energy Level  Playfulness Level  is_brachycephalic  ...  \
# count       9335   9335.000000        9335.000000        9335.000000  ...
# unique         6           NaN                NaN                NaN  ...
# top       Smooth           NaN                NaN                NaN  ...
# freq        4289           NaN                NaN                NaN  ...
# mean         NaN      3.839100           4.026352           0.170862  ...
# std          NaN      0.742243           0.753502           0.376409  ...
# min          NaN      3.000000           3.000000           0.000000  ...
# 25%          NaN      3.000000           3.000000           0.000000  ...
# 50%          NaN      4.000000           4.000000           0.000000  ...
# 75%          NaN      4.000000           5.000000           0.000000  ...
# max          NaN      5.000000           5.000000           1.000000  ...
#
#            Hum_Diff  CBT_simulated       is_old is_overweight  \
# count   9335.000000    9335.000000  9335.000000   9335.000000
# unique          NaN            NaN          NaN           NaN
# top             NaN            NaN          NaN           NaN
# freq            NaN            NaN          NaN           NaN
# mean       5.997905      39.130034     0.131441      0.299625
# std        3.527446       0.583020     0.337900      0.458118
# min       -0.920000      37.500000     0.000000      0.000000
# 25%        3.150000      38.722669     0.000000      0.000000
# 50%        5.640000      39.113383     0.000000      0.000000
# 75%        8.270000      39.520726     0.000000      1.000000
# max       20.750000      41.362771     1.000000      1.000000
#
#         heat_stress_risk  High_humidity_fordogs  \
# count        9335.000000            9335.000000
# unique               NaN                    NaN
# top                  NaN                    NaN
# freq                 NaN                    NaN
# mean            0.495126               0.298232
# std             0.500003               0.457507
# min             0.000000               0.000000
# 25%             0.000000               0.000000
# 50%             0.000000               0.000000
# 75%             1.000000               1.000000
# max             1.000000               1.000000
#
#         prior_heat_related_injury_est  simulated_heat_injury_flag  \
# count                     9335.000000                 9335.000000
# unique                            NaN                         NaN
# top                               NaN                         NaN
# freq                              NaN                         NaN
# mean                         0.023153                    0.023139
# std                          0.027103                    0.150352
# min                          0.000000                    0.000000
# 25%                          0.000000                    0.000000
# 50%                          0.012000                    0.000000
# 75%                          0.042000                    0.000000
# max                          0.102000                    1.000000
#
#         target2Category  target3Category
# count       9335.000000             9335
# unique              NaN                3
# top                 NaN           Normal
# freq                NaN             8151
# mean           0.126834              NaN
# std            0.332805              NaN
# min            0.000000              NaN
# 25%            0.000000              NaN
# 50%            0.000000              NaN
# 75%            0.000000              NaN
# max            1.000000              NaN
#
# [11 rows x 39 columns]

# %% [markdown]
# ### Visualize Numeric Attributes

# %%
# Visualize numeric attributes (w/o outliers)
print("BCS_cont and pct_of_ideal seem to have high variance. Consider factors?")
plt.figure(figsize=(12,6))
sns.boxplot(data=df[numeric_cols], orient="h")
plt.xlim(0,110) # comment this to visualize all data (including outliers)
plt.title("Boxplot of All Numeric Features w/o Outliers")
plt.xlabel("Value")
plt.ylabel("Feature")
plt.show()
# Out:
# BCS_cont and pct_of_ideal seem to have high variance. Consider factors?

# %%
# Visualize numeric attributes (w outliers)
print("Notable outliers with BCS_cont and pct_of_ideal")
plt.figure(figsize=(12,6))
sns.boxplot(data=df[numeric_cols], orient="h")
plt.title("Boxplot of All Numeric Features with Outliers")
plt.xlabel("Value")
plt.ylabel("Feature")
plt.show()
# Out:
# Notable outliers with BCS_cont and pct_of_ideal

# %%
skew_vals = df[numeric_cols].skew().sort_values(ascending=False)
print("Positive value is right skewed and negative value is left skewed\n")
print(skew_vals)
# Out:
# Positive value is right skewed and negative value is left skewed
#
# BCS_cont                         80.023241
# pct_of_ideal                     80.023241
# Ambient_Humidity                  2.209518
# Sun Exposure                      1.910398
# H_device                          1.808600
# Temp_Diff                         1.754693
# T_device                          1.700465
# prior_heat_related_injury_est     1.024077
# Hum_Diff                          0.706443
# breed_wt_mu                       0.479919
# breed_wt_sd                       0.467528
# Energy Level                      0.267053
# Ambient_Temp                      0.240902
# BCS                               0.184330
# CBT_simulated                     0.179361
# Weight                            0.017300
# Age                              -0.001701
# Station_Humidity                 -0.001717
# ideal_weight                     -0.028111
# Playfulness Level                -0.043367
# Station_Temp                     -0.415622
# Wind Cooling Effect              -2.703566
# dtype: float64
